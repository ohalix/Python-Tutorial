# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np


dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(15)
# Out:
#              job_title_short  \
# 568422        Data Scientist
# 642779          Data Analyst
# 702071          Data Analyst
# 58254           Data Analyst
# 527323  Senior Data Engineer
# 275402        Data Scientist
# 189582         Data Engineer
# 563004  Senior Data Engineer
# 131793        Data Scientist
# 495474        Cloud Engineer
# 490267         Data Engineer
# 658328        Data Scientist
# 508373        Data Scientist
# 274065         Data Engineer
# 94722          Data Engineer
#
#                                                 job_title  \
# 568422                            Data Science Internship
# 642779         Sales Project Coordinator and Data Analyst
# 702071                               Workday Data Analyst
# 58254                                     Sr Data Analyst
# 527323                         Senior Data Engineer - H/F
# 275402                                  Database Engineer
# 189582   Data Engineer databases, SQL en Data Warehousing
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'id'

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Methods to cover
# - df.reset_index()
# - df.set_index()
# - df.sort_index()

# %%
df_nig = df[df['job_country'] == 'Nigeria']

df_nig = df_nig.drop_duplicates(subset= ['job_title', 'company_name'])

# %%
df_nig.reset_index(inplace= True)

# %%
df_nig.set_index('id', inplace= True)

# %%
df_nig[df_nig['salary_rate'].isna() == False]
# Out:
#           job_title_short                                          job_title  \
# id
# 78381        Data Analyst  Human Resources Data Analyst, Dangote Cement T...
# 95214    Business Analyst                                         BI Analyst
# 166888     Data Scientist                                 Jr. Data Scientist
# 198573   Business Analyst  Analyst – Business Analytics Visualisation, Ma...
# 357444      Data Engineer                                      Data Engineer
# 399244       Data Analyst                  Data Analytics & Insights Officer
# 437247   Business Analyst                      Head, Research and Innovation
# 537048       Data Analyst                          Data Analyst - Operations
# 610994  Software Engineer  Senior Software Engineer Opportunities at Heli...
# 774264     Data Scientist             Head of Data and Research Methods Unit
# 777877   Business Analyst              Senior Business Intelligence Engineer
#
# ...
