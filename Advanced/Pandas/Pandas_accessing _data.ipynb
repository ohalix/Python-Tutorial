# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np


dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.loc[:, 'salary_rate': 'salary_hour_avg'].dropna(subset='salary_rate')
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
df.loc[[6338, 88732, 3642, 524282, 73529]].dropna(subset= 'job_title')
# Out:
#              job_title_short                                      job_title  \
# 6338          Data Scientist                      ESI 33 Data scientist H/F
# 88732          Data Engineer  Engineering Director - Data & Analytics Tribe
# 3642           Data Engineer                                  Data Engineer
# 524282        Data Scientist                       Marketing Data Scientist
# 73529   Senior Data Engineer                           Senior Data Engineer
#
#                                              job_location          job_via  \
# 6338                              Castres-Gironde, France     via Jobijoba
# 88732   Kuala Lumpur, Federal Territory of Kuala Lumpu...      via Denmark
# 3642                                            Sandy, UT  via Trabajo.org
# 524282                                        Shelton, CT  via Trabajo.org
# 73529                                            Anywhere  via Recruit.net
#
#        job_schedule_type  job_work_from_home          search_location  \
# 6338           Full-time               False                   France
# 88732          Full-time               False                 Malaysia
# 3642           Full-time               False                  Georgia
# 524282         Full-time               False  New York, United States
# 73529          Full-time                True  Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 6338   2023-06-26 13:48:59                  False                 False
# 88732  2023-10-20 01:09:11                   True                 False
# 3642   2023-12-02 13:46:03                  False                 False
# 524282 2023-09-06 11:01:24                  False                 False
# 73529  2023-01-09 00:06:33                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 6338           France        None              NaN              NaN
# 88732        Malaysia        None              NaN              NaN
# 3642    United States        None              NaN              NaN
# 524282  United States        None              NaN              NaN
# 73529   United States        None              NaN              NaN
#
#                   company_name  \
# 6338                 Ac Amiens
# 88732                    SWIFT
# 3642            Insight Global
# 524282  Discount School Supply
# 73529                   Engtal
#
#                                                job_skills  \
# 6338    ['sas', 'sas', 'java', 'css', 'html', 'javascr...
# 88732                                  ['swift', 'excel']
# 3642    ['t-sql', 'sql', 'postgresql', 'sql server', '...
# 524282                                    ['python', 'r']
# 73529   ['python', 'sql', 'go', 'java', 'elasticsearch...
#
#                                           job_type_skills
# 6338    {'analyst_tools': ['sas'], 'databases': ['post...
# 88732   {'analyst_tools': ['excel'], 'programming': ['...
# 3642    {'analyst_tools': ['ssis'], 'databases': ['pos...
# 524282                   {'programming': ['python', 'r']}
# 73529   {'cloud': ['databricks', 'aws', 'azure', 'gcp'...
